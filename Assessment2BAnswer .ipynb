# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
data = pd.concat(map(pd.read_csv, ['/content/college_1.csv','/content/college_2.csv']), ignore_index=True)
df = pd.DataFrame(data)
df
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 114  praveen raj j    24.0    0.0               2380            2380
# 115     AMARNATH D    -1.0   12.0               1890            1890
# 116           bala    32.0    0.0               1720            1720
# 117           XY Z    -1.0   -1.0                  0               0
# 118      Hariharan    -1.0   -1.0                  0               0
#
#                                     Department  Rising  python_en  \
# 0             Computer Science and Engineering       0        NaN
# ...

# %%
df.shape
# Out:
# (119, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    119 non-null    object
#  1   python                  119 non-null    float64
#  2   mysql                   119 non-null    float64
#  3   Previous Geekions       119 non-null    int64
#  4   CodeKata Score          119 non-null    int64
#  5   Department              119 non-null    object
#  6   Rising                  119 non-null    int64
#  7   python_en               35 non-null     float64
#  8   computational_thinking  35 non-null     float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 8.5+ KB

# %%
df.isna().sum()
# Out:
# Name                       0
# python                     0
# mysql                      0
# Previous Geekions          0
# CodeKata Score             0
# Department                 0
# Rising                     0
# python_en                 84
# computational_thinking    84
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Name                       0
# python                     0
# mysql                      0
# Previous Geekions          0
# CodeKata Score             0
# Department                 0
# Rising                     0
# python_en                 84
# computational_thinking    84
# dtype: int64

# %%
df.describe()
# Out:
#            python       mysql  Previous Geekions  CodeKata Score       Rising  \
# count  119.000000  119.000000         119.000000      119.000000   119.000000
# mean    54.352941   23.500000        3842.352941     4051.764706   209.411765
# std     44.272526   33.276671        4406.339992     4551.951881   553.445746
# min     -1.000000   -1.000000           0.000000        0.000000     0.000000
# 25%      0.000000    0.000000         740.000000      740.000000     0.000000
# 50%     82.000000    4.000000        2410.000000     2410.000000     0.000000
# 75%    100.000000   33.000000        5340.000000     5975.000000     0.000000
# max    100.000000  100.000000       24500.000000    24500.000000  3140.000000
#
#         python_en  computational_thinking
# count   35.000000               35.000000
# mean    29.657143                2.200000
# std     30.582524                7.015948
# min     -1.000000               -1.000000
# 25%      0.000000                0.000000
# ...

# %%
df.to_csv("Mergedfile.csv")

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
# if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv
Exceeded_expectations=df[df["CodeKata Score"] > 15000]
df1=pd.DataFrame(Exceeded_expectations)
df1.to_csv('Exceeded expectations.csv',index=False)

# %%
#if 10000<codekata score<15000 (Reached_expectations.csv)
Reached_expectations=df[(df['CodeKata Score'] > 10000) & (df['CodeKata Score'] < 15000)]
df2=pd.DataFrame(Reached_expectations)
df2.to_csv('Reached_expectations.csv',index=False)

# %%
#if 7000<codekata score<10000 (Needs_Improvement.csv)
Needs_Improvement=df[(df['CodeKata Score'] > 7000) & (df['CodeKata Score'] < 10000)]
df3=pd.DataFrame(Needs_Improvement)
df3.to_csv('Needs_Improvement.csv',index=False)

# %%
#if codekate score < 7000 (Unsatisfactory.csv)
Unsatisfactory=df[df['CodeKata Score'] < 7000]
df4=pd.DataFrame(Unsatisfactory)
df4.to_csv('Unsatisfactory.csv',index=False)

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
df5=df[['Previous Geekions','CodeKata Score']].mean()
df5
# Out:
# Previous Geekions    3842.352941
# CodeKata Score       4051.764706
# dtype: float64

# %% [markdown]
# ###### No of students participated

# %%
df['Name'].count()
# Out:
# 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
df6=df.sort_values(by="Previous Geekions",ascending=False)
df6.iloc[0:3]["Name"].str.upper()
# Out:
# 0      A.DHARANI
# 1    V.JEEVITHA
# 2    HEMAVATHI.R
# Name: Name, dtype: object

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
fig_pie=px.pie(df,values="CodeKata Score",names="Department") #value represent numerical data,names-categorical data
fig_pie.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
df7=df.sort_values(by="Department",ascending=True)
df7
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 85         Chandru     0.0    0.0              14150           14490
# 76            Arun    95.0    4.0                 40              40
# 69      karthika.G   100.0    0.0                120             120
# 66  Evanasundari.K    61.0    0.0                180             180
# ..             ...     ...    ...                ...             ...
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 79    KarthikeyanS    45.0    0.0                  0               0
# 64      k.parvathi   100.0  100.0                260             260
# 77      J.JAYANTHI   100.0  100.0                 40              40
#
#                                 Department  Rising  python_en  \
# 0         Computer Science and Engineering       0        NaN
# ...

# %%
df7['total']=df7[['python','mysql','Previous Geekions','CodeKata Score','python_en','computational_thinking']].sum(axis=1)
df7
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 85         Chandru     0.0    0.0              14150           14490
# 76            Arun    95.0    4.0                 40              40
# 69      karthika.G   100.0    0.0                120             120
# 66  Evanasundari.K    61.0    0.0                180             180
# ..             ...     ...    ...                ...             ...
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 79    KarthikeyanS    45.0    0.0                  0               0
# 64      k.parvathi   100.0  100.0                260             260
# 77      J.JAYANTHI   100.0  100.0                 40              40
#
#                                 Department  Rising  python_en  \
# 0         Computer Science and Engineering       0        NaN
# ...

# %%
df7
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 85         Chandru     0.0    0.0              14150           14490
# 76            Arun    95.0    4.0                 40              40
# 69      karthika.G   100.0    0.0                120             120
# 66  Evanasundari.K    61.0    0.0                180             180
# ..             ...     ...    ...                ...             ...
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 79    KarthikeyanS    45.0    0.0                  0               0
# 64      k.parvathi   100.0  100.0                260             260
# 77      J.JAYANTHI   100.0  100.0                 40              40
#
#                                 Department  Rising  python_en  \
# 0         Computer Science and Engineering       0        NaN
# ...

# %%
df7["Department"].value_counts()
# Out:
# Computer Science and Engineering             63
# Electronics and Communication Engineering    39
# Electronics and Electrical Engineering       17
# Name: Department, dtype: int64

# %%
CSC=df7[df7['Department']== 'Computer Science and Engineering'].max()
EEE=df7[df7['Department']== 'Electronics and Electrical Engineering'].max()
ECE=df7[df7['Department']== 'Electronics and Communication Engineering'].max()

# %%
df8 = pd.concat([CSC,EEE,ECE],axis=1)
df8.T # TRANSPOSE T will be used as col to row and vice versa
# Out:
#              Name python  mysql Previous Geekions CodeKata Score  \
# 0     vijayakumar  100.0  100.0             24500          24500
# 1  yaser ahamed.A  100.0  100.0             19400          19400
# 2       vignesh B  100.0  100.0             10040          10040
#
#                                   Department Rising python_en  \
# 0           Computer Science and Engineering   2000      78.0
# 1     Electronics and Electrical Engineering   3140     100.0
# 2  Electronics and Communication Engineering    560      72.0
#
#   computational_thinking    total
# 0                    9.0  49102.0
# 1                    9.0  38940.0
# 2                   39.0  20113.0

# %%
df8['total']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-7f580324f0f0> in <module>()
# ----> 1 df8['total']
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     386                 except ValueError as err:
#     387                     raise KeyError(key) from err
# --> 388             raise KeyError(key)
#     389         return super().get_loc(key, method=method, tolerance=tolerance)
#     390
#
# KeyError: 'total'

# %%
df8.plot(kind='scatter',x='Department',y='total',color='red')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Department'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-c21cfa560758> in <module>()
# ----> 1 df8.plot(kind='scatter',x='Department',y='total',color='red')
# ...

# %%
df8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, Name to total
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       10 non-null     object
#  1   1       10 non-null     object
#  2   2       10 non-null     object
# dtypes: object(3)
# memory usage: 620.0+ bytes
